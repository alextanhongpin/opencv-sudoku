# %%
# %matplotlib inline

import cv2
import matplotlib.pyplot as plt
import numpy as np
# from four_point_transform import four_point_transform
from imutils.perspective import four_point_transform # Scipy is required.
from skimage.segmentation import clear_border # scikit-image is required.
from tensorflow.keras.preprocessing.image import img_to_array

import pytesseract
import imutils
import math

# %%
def draw(img):
    plt.figure(figsize=(10, 10))
    plt.imshow(img, cmap='gray')

# %%
# Train custom mnist because pytesseract is not accurate.
# python3 -m pip install --upgrade https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.12.0-py3-none-any.whl

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelBinarizer

def build(width, height, depth, classes):
    model = Sequential()
    input_shape = (height, width, depth)

    # First set of CONV => RELU => POOL layers.
    model.add(Conv2D(32, (5, 5), padding='same',
                     input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    
    # Second set of CONV => RELU => POOL layers.
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # Fully-connected layer set with 50% dropout.
    # First set of FC => RELU layers.
    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    
    # Second set of FC => RELU layers.
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    
    # Softmax classifier.
    model.add(Dense(classes))
    model.add(Activation('softmax'))
    
    return model

# Initialize the initial learning rate, number of epochs to train and batch size.
INIT_LR = 1e-3
EPOCHS = 10
BS = 128

(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# Add a channel (grayscale dimension) to the digits.
train_data = train_data.reshape((train_data.shape[0], 28, 28, 1))
test_data = test_data.reshape((test_data.shape[0], 28, 28, 1))

# Scale data to the range [0, 1]
train_data = train_data.astype('float32') / 255.0
test_data = test_data.astype('float32') / 255.0

# Convert the labels from integers to vectors.
le = LabelBinarizer()
train_labels = le.fit_transform(train_labels)
test_labels = le.fit_transform(test_labels)

opt = Adam(lr=INIT_LR)
model = build(width=28, height=28, depth=1, classes=10)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
h = model.fit(train_data, train_labels, 
                 validation_data =(test_data, test_labels),
                 batch_size=BS,
                 epochs=EPOCHS,
                 verbose=1)

predictions = model.predict(test_data)
print(classification_report(test_labels.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=[str(x) for x in le.classes_]))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 57s 953us/step - loss: 0.7314 - acc: 0.7564 - val_loss: 0.1031 - val_acc: 0.9714
# Epoch 2/10
# 60000/60000 [==============================] - 69s 1ms/step - loss: 0.2605 - acc: 0.9238 - val_loss: 0.0621 - val_acc: 0.9809
# Epoch 3/10
# 60000/60000 [==============================] - 58s 964us/step - loss: 0.1992 - acc: 0.9413 - val_loss: 0.0486 - val_acc: 0.9857
# Epoch 4/10
# 60000/60000 [==============================] - 52s 870us/step - loss: 0.1669 - acc: 0.9514 - val_loss: 0.0482 - val_acc: 0.9855
# Epoch 5/10
# 60000/60000 [==============================] - 52s 860us/step - loss: 0.1471 - acc: 0.9581 - val_loss: 0.0433 - val_acc: 0.9871
# Epoch 6/10
# 60000/60000 [==============================] - 53s 883us/step - loss: 0.1358 - acc: 0.9607 - val_loss: 0.0386 - val_acc: 0.9891
# Epoch 7/10
# ...

# %%
# Serialize the model to disk.
model.save('digits_classifier.h5')

# %%
src = 'sudoku.jpeg'
img = cv2.imread(src)
draw(img)

# %%
# Convert image to grayscale.
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
draw(gray)

# %%
# Smooth image by applying median blur.
# blur = cv2.medianBlur(gray, 5)
blur = cv2.GaussianBlur(gray, (7, 7), 3)
draw(blur)

# Apply threshold
block_size=11
c=2
thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, block_size, c)
draw(thresh)

cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL,
                        cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

puzzleCnt = None
for c in cnts:
    # Approximate the contour.
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)
    
    # If our approximated contour has four points, then we can assume we have 
    # found the outline of the puzzle. Since it was sorted based on area,
    # we will always get the largest box first.
    if len(approx) == 4:
        puzzleCnt = approx
        break

if puzzleCnt is None:
    raise Exception('Could not find Sudoku puzzle outline. Try debugging your thresholding and contour step.')

output = img.copy()
cv2.drawContours(output, [puzzleCnt], -1, (0, 255, 0), 2)
draw(output)



puzzle = four_point_transform(img, puzzleCnt.reshape(4, 2))
warped = four_point_transform(gray, puzzleCnt.reshape(4, 2))
draw(puzzle)
draw(warped)

def extract_digit(cell):
    thresh = cv2.threshold(cell, 0, 255, cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)[1]
    # thresh = cv2.adaptiveThreshold(cell, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)

    thresh = clear_border(thresh)
    
    # Find contours in the thresholded cell.
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    # If no contours were found, then the cell is empty.
    if len(cnts) == 0:
        return None
    
    # Otherwise find the largest contour in the cell and create a mask for the contour.
    c = max(cnts, key=cv2.contourArea)
    mask = np.zeros(thresh.shape, dtype='uint8')
    cv2.drawContours(mask, [c], -1, 255, -1)
    
    # Compute the percentage of masked pixels relative to the total area of the image
    h, w = thresh.shape
    percent_filled = cv2.countNonZero(mask) / float(w * h)
    
    # If less than 3 percent of the mask is filled then we are looking at noise
    # and can safely ignore the contour.
    if percent_filled < 0.03:
        return None
    
    # Apply the mask to the thresholded cell.
    digit = cv2.bitwise_and(thresh, thresh, mask=mask)
    return digit
    

sudoku = [[None] * 9 for i in range(9)]
# extract_digit(warped)
out = warped.copy()


height, width = warped.shape
cell_width = math.ceil(width / 9) # Take as large the area as possible.
cell_height = math.ceil(height / 9)
for i in range(9):
    for j in range(9):
        x0, x1 = i*cell_width, (i+1)*cell_width
        y0, y1 = j*cell_height, (j+1)*cell_height
        roi = warped[y0:y1, x0:x1]
        out = cv2.rectangle(out, (x0, y0), (x1, y1), (0, 255, 0), 1)
        digit = extract_digit(roi)
        if digit is not None:
#             draw(digit)
#             text = pytesseract.image_to_string(digit, lang='eng', config='--oem 1 --psm 6') # Needs to be enabled to read single digit.
            # text = pytesseract.image_to_string(digit, lang='eng', config='--oem 3 --psm 10 -c tessedit_char_whitelist=0123456789') # Needs to be enabled to read single digit.
    
            # Resize the image to 28x28 and then prepare the cells for classification.
            roi = cv2.resize(digit, (28, 28))
            roi = roi.astype('float')/255.0
            roi = img_to_array(roi)
            roi = np.expand_dims(roi, axis=0)
            text = model.predict(roi).argmax(axis=1)[0]
            
            sudoku[j][i] = text

draw(out)

sudoku
# Out:
# [[None, None, None, 6, None, None, None, None, None],
#  [7, None, 6, None, None, None, None, None, 9],
#  [None, None, None, None, None, 5, None, 8, None],
#  [None, 7, None, None, 2, None, None, 9, 3],
#  [8, None, None, None, None, None, None, None, 5],
#  [4, 8, None, None, 7, None, None, 7, None],
#  [None, 5, None, 2, None, None, None, None, None],
#  [3, None, None, None, None, None, 2, None, 8],
#  [None, None, 2, 3, None, 1, None, None, None]]

# %%
# Sharpen image to enhance edges.
# sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
# sharpen = cv2.filter2D(blur, -1, sharpen_kernel)
# draw(sharpen)

# %%
# kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
# close = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)
# draw(close)

# %%
# NOTE: This method of finding contour does not solve for warped boxes.
# Find all contours.
def getSkewAngle(img):
    img = img.copy()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blur = cv2.medianBlur(gray, 3)
    block_size=15
    c=5
    thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, block_size, c)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    close = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=3)

    contours, hierarchy = cv2.findContours(close, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find contours with the largest area.
    contours = sorted(contours, key=cv2.contourArea, reverse = True)

    # Find largest contour and surround in min area box
    largest_contour = contours[0]
    min_area_rect = cv2.minAreaRect(largest_contour)

    # Determine the angle. Convert it to the value that was originally used to obtain skewed image
    angle = min_area_rect[-1]
    if angle < -45:
        angle = 90 + angle
    return angle

# Rotate the image around its center
def rotateImage(img, angle: float):
    img = img.copy()
    (h, w) = img.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    out = cv2.warpAffine(img, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return out

# Deskew image
def deskew(img):
    img = img.copy()
    angle = getSkewAngle(img)
    return rotateImage(img, angle)

draw(deskew(img))

# Draw border.
# x, y, w, h = cv2.boundingRect(contours[0])
# target = rotated_img[y:y+h,x:x+w].copy()
# cv2.rectangle(target, (0, 0), (w, h), (36,255,12), 2)
# draw(target)

# out = img.copy()
# cv2.rectangle(out, (x, y), (x+w, y+h), (36,255,12), 2)
# draw(out)

# cropped = gray[y:y+h,x:x+w].copy()

# %% [markdown]
# ##
